# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import pydot
import seaborn as sns


from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV


import tensorflow as tf
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv("fashion-mnist_train.csv")
fashion_test=pd.read_csv("fashion-mnist_test.csv")

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
X_train_fashion = fashion_train.drop('label',axis = 1)
y_train_fashion = fashion_train['label']
X_test_fashion = fashion_test.drop('label',axis = 1)
y_test_fashion = fashion_test['label']

# %%
x_train_reshape = X_train_fashion.values.reshape(-1,28,28)
x_test_reshape = X_test_fashion.values.reshape(-1,28,28)


col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']


plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])
plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)

y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(10,activation='softmax'),
])


model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])


history=model.fit(X_train_fashion, y_train_fashion, batch_size=100, epochs=30,validation_data=(X_test_fashion, y_test_fashion))
# Out:
# Epoch 1/30
# 600/600 [==============================] - 38s 17ms/step - loss: 1.1117 - accuracy: 0.6267 - val_loss: 0.5374 - val_accuracy: 0.8159
# Epoch 2/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.7359 - accuracy: 0.7494 - val_loss: 0.4640 - val_accuracy: 0.8429
# Epoch 3/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.6581 - accuracy: 0.7778 - val_loss: 0.4492 - val_accuracy: 0.8417
# Epoch 4/30
# 600/600 [==============================] - 11s 19ms/step - loss: 0.6339 - accuracy: 0.7884 - val_loss: 0.4730 - val_accuracy: 0.8380
# Epoch 5/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.6085 - accuracy: 0.7972 - val_loss: 0.4617 - val_accuracy: 0.8547
# Epoch 6/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5943 - accuracy: 0.8040 - val_loss: 0.4758 - val_accuracy: 0.8490
# Epoch 7/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5783 - accuracy: 0.8079 - val_loss: 0.4557 - val_accuracy: 0.8578
# Epoch 8/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5697 - accuracy: 0.8091 - val_loss: 0.4382 - val_accuracy: 0.8596
# Epoch 9/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5680 - accuracy: 0.8095 - val_loss: 0.4576 - val_accuracy: 0.8551
# Epoch 10/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5566 - accuracy: 0.8149 - val_loss: 0.4350 - val_accuracy: 0.8628
# Epoch 11/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5518 - accuracy: 0.8159 - val_loss: 0.4408 - val_accuracy: 0.8589
# Epoch 12/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5450 - accuracy: 0.8187 - val_loss: 0.4549 - val_accuracy: 0.8602
# Epoch 13/30
# 600/600 [==============================] - 10s 17ms/step - loss: 0.5381 - accuracy: 0.8222 - val_loss: 0.4397 - val_accuracy: 0.8641
# Epoch 14/30
# 600/600 [==============================] - 10s 16ms/step - loss: 0.5332 - accuracy: 0.8226 - val_loss: 0.4416 - val_accuracy: 0.8672
# Epoch 15/30
# 600/600 [==============================] - 10s 17ms/step - loss: 0.5349 - accuracy: 0.8199 - val_loss: 0.4325 - val_accuracy: 0.8687
# Epoch 16/30
# 600/600 [==============================] - 10s 17ms/step - loss: 0.5365 - accuracy: 0.8186 - val_loss: 0.4457 - val_accuracy: 0.8668
# Epoch 17/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5292 - accuracy: 0.8219 - val_loss: 0.4422 - val_accuracy: 0.8627
# Epoch 18/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5315 - accuracy: 0.8205 - val_loss: 0.4339 - val_accuracy: 0.8685
# Epoch 19/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5266 - accuracy: 0.8235 - val_loss: 0.4454 - val_accuracy: 0.8632
# Epoch 20/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5233 - accuracy: 0.8240 - val_loss: 0.4385 - val_accuracy: 0.8646
# Epoch 21/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5243 - accuracy: 0.8239 - val_loss: 0.4156 - val_accuracy: 0.8670
# Epoch 22/30
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5111 - accuracy: 0.8289 - val_loss: 0.4215 - val_accuracy: 0.8620
# Epoch 23/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5143 - accuracy: 0.8287 - val_loss: 0.4018 - val_accuracy: 0.8659
# Epoch 24/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5101 - accuracy: 0.8294 - val_loss: 0.4015 - val_accuracy: 0.8684
# Epoch 25/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5073 - accuracy: 0.8309 - val_loss: 0.4231 - val_accuracy: 0.8712
# Epoch 26/30
# 600/600 [==============================] - 10s 16ms/step - loss: 0.5058 - accuracy: 0.8297 - val_loss: 0.4135 - val_accuracy: 0.8715
# Epoch 27/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5059 - accuracy: 0.8322 - val_loss: 0.4091 - val_accuracy: 0.8656
# Epoch 28/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.4974 - accuracy: 0.8348 - val_loss: 0.4099 - val_accuracy: 0.8673
# Epoch 29/30
# 600/600 [==============================] - 9s 16ms/step - loss: 0.5026 - accuracy: 0.8319 - val_loss: 0.5772 - val_accuracy: 0.8702
# Epoch 30/30
# 600/600 [==============================] - 10s 16ms/step - loss: 0.4934 - accuracy: 0.8358 - val_loss: 0.3821 - val_accuracy: 0.8741

# %%
test_loss_fashion, test_acc_fashion = model.evaluate(X_test_fashion, y_test_fashion)
# Out:
# 313/313 [==============================] - 3s 6ms/step - loss: 0.3821 - accuracy: 0.8741

# %%
print('Fashion MNIST Test accuracy:', round(test_acc_fashion,4))
# Out:
# Fashion MNIST Test accuracy: 0.8741

# %%
y_predict_fash = model.predict(X_test_fashion)
y_predict_fash=np.argmax(y_predict_fash, axis=1)
y_test_fash_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
con_mat=confusion_matrix(y_test_fash_eval,y_predict_fash)
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,10))
sns.heatmap(con_mat,annot=True,annot_kws={'size': 15},linewidths=0.5,fmt="d",cmap="gray")
plt.title('True or False predicted Fashion MNIST\n',fontweight='bold',fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_fash_eval,y_predict_fash))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83      1000
#            1       0.99      0.98      0.98      1000
#            2       0.81      0.76      0.78      1000
#            3       0.89      0.91      0.90      1000
#            4       0.76      0.85      0.80      1000
#            5       0.92      0.96      0.94      1000
#            6       0.73      0.59      0.65      1000
#            7       0.94      0.92      0.93      1000
#            8       0.97      0.96      0.97      1000
#            9       0.94      0.94      0.94      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
y_predict = model.predict(X_test_fashion.loc[[0],:].values)
y_predict=np.argmax(y_predict, axis=1) 
y_test_digit_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# 1/1 [==============================] - 0s 109ms/step

# %%
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

plt.figure(figsize=(10,10))
plt.imshow(x_train_reshape[0], cmap='gray')
plt.xlabel("Actual:{},Pred:{}".format(col_names[np.argmax(y_test_fashion[0])],col_names[y_predict[0]]))
plt.show()
